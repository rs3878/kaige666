# %%
0a0e8c15b.json

# %%
import json
import pprint
with open('data/train_sentiment/0a0e8c15b.json') as f:
    d = json.load(f)
    pprint.pprint(d)
# Out:
# {'categories': [],
#  'documentSentiment': {'magnitude': 1.9, 'score': 0.3},
#  'entities': [{'mentions': [{'text': {'beginOffset': -1, 'content': 'Fenny'},
#                              'type': 'PROPER'},
#                             {'text': {'beginOffset': -1, 'content': 'girl'},
#                              'type': 'COMMON'}],
#                'metadata': {},
#                'name': 'Fenny',
#                'salience': 0.7863105,
#                'type': 'PERSON'},
#               {'mentions': [{'text': {'beginOffset': -1, 'content': 'market'},
#                              'type': 'COMMON'}],
#                'metadata': {},
#                'name': 'market',
#                'salience': 0.08208243,
#                'type': 'OTHER'},
#               {'mentions': [{'text': {'beginOffset': -1,
#                                       'content': 'Old Klang Rd'},
#                              'type': 'PROPER'}],
#                'metadata': {},
# ...
