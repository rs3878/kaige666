# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model, svm
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
% matplotlib inline
import seaborn as sns
import re

# %%
data = pd.read_csv("data/train.csv")
description = data['Description'][0:100]

# %%
# converting all letters to lower or upper case  
for i,item in description.iteritems():
    if type(item) != float:
        description[i] = item.lower()

# %%
# converting numbers into words or removing numbers  
for i,item in description.iteritems():
    if type(item) != float:
        description[i] = re.sub(r'\d+', '', item)

# %%
# removing punctuations, accent marks and other diacritics  
for i,item in description.iteritems():
    if type(item) != float:
        result = re.sub('[^\w\s]', '', item)
        description[i] = result

# %%
# removing white spaces
for i,item in description.iteritems():
    if type(item) != float:
        description[i] = item.strip()

# %%
# removing stop words, sparse terms, and particular words
import nltk #nltk represents natural language toolkit
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

from nltk.tokenize import word_tokenize
for index,item in description.iteritems():
    if type(item) != float:
        tokens = word_tokenize(item)
        result = [i for i in tokens if not i in stop_words]
        description[index] = result

# %%
# text canonicalization: stemming 词干提取
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
stemmer = PorterStemmer()

for i,item in description.iteritems():
    if type(item) != float:
        for index, word in enumerate(item):
            description[i][index] = stemmer.stem(word)

# %%
# text canonicalization: lemmatization 词形还原 
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer() # uses lexical knowledge bases to get the correct base forms of words.

for i,item in description.iteritems():
    if type(item) != float:
        for index, word in enumerate(item):
            description[i][index] = lemmatizer.lemmatize(word)

# %%
description
# Out:
# 0     [nibbl, month, old, ball, cute, energet, play,...
# 1     [found, alon, yesterday, near, apart, shake, b...
# 2     [pregnant, mother, dump, irrespons, owner, roa...
# 3     [good, guard, dog, alert, activ, obedi, wait, ...
# 4     [handsom, yet, cute, boy, adopt, play, pal, we...
# 5               [stray, kitten, came, hous, feed, keep]
# 6     [anyon, within, area, ipoh, taip, interest, ad...
# 7     [siu, pak, give, birth, puppi, interest, pl, c...
# 8     [healthi, activ, feisti, kitten, found, neighb...
# 9     [manja, gentl, stray, cat, found, would, reall...
# 10       [seriou, adopt, plea, sm, call, detail, thank]
# 11    [kali, super, play, kitten, go, minut, wake, q...
# 12    [peanut, abus, puppi, rescu, scare, peopl, hap...
# 13    [hi, pet, lover, first, post, need, help, mont...
# 14    [lost, dog, found, bandar, menjalara, kepongta...
# 15    [move, apart, land, home, mani, friendli, stra...
# 16                               [spay, ador, friendli]
# 17    [she, activ, obey, wht, command, u, told, exam...
# 18    [cuti, dump, owner, market, almost, kill, car,...
# 19    [birth, date, oct, th, kitti, melli, femal, sa...
# 20    [godiva, rescu, serdang, residenti, area, grou...
# 21    [three, puppi, abandon, street, pick, fed, pro...
# 22    [cat, name, kenit, kenotowen, keyad, manja, te...
# 23    [donut, friendli, doggi, domest, bark, strange...
# 24    [hello, cikenet, fan, wan, na, inform, cikenet...
# 25    [garfield, larg, cat, need, daili, groom, groo...
# 26     [healthi, toilet, train, cute, easi, look, play]
# 27    [save, kitten, street, mani, dog, home, could,...
# 28    [healthi, activ, skinni, tall, mother, doberma...
# 29    [kitten, found, roadsid, stay, keep, meow, kit...
#                             ...
# 70    [rescu, qiqi, sibl, xiao, bai, year, ago, floo...
# 71                                         [dog, adopt]
# 72    [monthold, male, puppi, adopt, cross, two, pur...
# 73    [he, rescu, industri, park, activ, way, cure, ...
# 74    [two, litter, puppi, adopt, breed, includ, ame...
# 75    [hi, coco, rescu, puppi, street, would, like, ...
# 76    [beauti, puppi, left, park, front, hous, raini...
# 77    [adopt, drive, citta, mall, month, old, activ,...
# 78                                              [adopt]
# 79    [puppi, current, live, abandon, carpark, adopt...
# 80    [puppi, save, mpsp, pound, yesterday, heathi, ...
# 81    [best, breed, train, easili, playfultoilet, si...
# 82    [tanto, needa, good, homeh, beauti, ppl, perso...
# 83    [love, puppi, good, natur, look, home, sweet, ...
# 84    [read, stori, male, she, activeplay, healthi, ...
# 85    [ador, cute, puppi, commit, spay, reach, month...
# 86    [ive, lulu, sinc, week, old, well, behav, trai...
# 87    [found, dog, roadsid, think, abandon, rottweil...
# 88    [nickki, mix, breedfemal, one, year, plu, fast...
# 89    [mochi, momo, molli, sibl, month, old, black, ...
# 90    [puppi, five, week, old, look, good, home, fam...
# 91    [rescuer, road, side, shiver, meow, non, stop,...
# 92    [mother, puppi, found, bayu, tinggi, klang, mr...
# 93    [saya, jumpa, kuce, ini, yang, datang, di, rum...
# 94                              [locat, klang, contact]
# 95    [heihei, pick, penang, spca, th, apr, brother,...
# 96                                                  NaN
# 97    [cute, obedi, friendli, play, activ, littl, pu...
# 98    [plea, adopt, need, home, urgent, locat, jalan...
# 99                                      [owner, desert]
# Name: Description, Length: 100, dtype: object

# %% [markdown]
# # Alternatively

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
data = pd.read_csv("data/train.csv")
corpus = data['Description'][0:100]

# %%
vectorizer = CountVectorizer(stop_words='english')

# %%
for i in range(len(corpus)):
    if type(corpus[i]) == float:
        corpus[i] = ""

# %%
X = vectorizer.fit_transform(corpus)

# %%
vectorizer.get_feature_names()
# Out:
# ['10',
#  '11',
#  '11a',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '19',
#  '1g',
#  '1st',
#  '23',
#  '24th',
#  '25',
#  '2female',
#  '2month',
#  '2months',
#  '2nd',
#  '2years',
#  '30mins',
#  '30th',
#  '45',
#  '6puppies',
#  '6th',
#  '9th',
#  '________________________________________________',
#  '___________________________________________________',
#  'abandoned',
#  'abang',
#  'able',
#  'abroad',
#  'absolutely',
#  'abused',
#  'acceptable',
#  'accident',
#  'act',
#  'action',
#  'active',
#  'actually',
#  'ada',
#  'addopt',
#  'address',
#  'adjustable',
#  'adopt',
#  'adopted',
#  'adopter',
#  'adopters',
#  'adopting',
#  'adoption',
#  'adopts',
#  'adorable',
#  'adult',
#  'adventurous',
#  'affection',
#  'affectionate',
#  'afraid',
#  'age',
#  'ago',
#  'agree',
#  'alert',
#  'alertness',
#  'alike',
#  'allow',
#  'allowed',
#  'almond',
#  'amat',
#  'amer',
#  'american',
#  'angel',
#  'ank',
#  'anybody',
#  'anyybody',
#  'apartment',
#  'apologise',
#  'app',
#  'appear',
#  'apply',
#  'appreciate',
#  'apr',
#  'ard',
#  'area',
#  'aren',
#  'arranged',
#  'aside',
#  'ask',
#  'asked',
#  'asyik',
#  'attached',
#  'attention',
#  'atwhat',
#  'authorities',
#  'available',
#  'away',
#  'babies',
#  'baby',
#  'badan',
#  'baginya',
#  'bahaya',
#  'bai',
#  'baik',
#  'baik2',
#  'ball',
#  'bandar',
#  'bark',
#  'barking',
#  'barkly',
#  'based',
#  'basic',
#  'batch',
#  'bath',
#  'bathroom',
#  'bayu',
#  'bcos',
#  'beautiful',
#  'beautifully',
#  'beauty',
#  'bed',
#  'befriended',
#  'behave',
#  'behaved',
#  'belakang',
#  'beliau',
#  'believe',
#  'believed',
#  'beloved',
#  'belt',
#  'ben',
#  'benji',
#  'bergaduh',
#  'best',
#  'betine',
#  'better',
#  'big',
#  'birth',
#  'bit',
#  'black',
#  'bless',
#  'blossom',
#  'blue',
#  'bo',
#  'bodies',
#  'body',
#  'boiboi',
#  'boleh',
#  'booked',
#  'boost',
#  'boots',
#  'born',
#  'borne',
#  'bottle',
#  'bouncer',
#  'boy',
#  'boys',
#  'brat',
#  'breed',
#  'breeds',
#  'bring',
#  'bro',
#  'brother',
#  'brothers',
#  'brown',
#  'brushing',
#  'buang',
#  'bukit',
#  'bulan',
#  'bulat',
#  'bull',
#  'bushes',
#  'busy',
#  'buyers',
#  'cage',
#  'caged',
#  'caging',
#  'calico',
#  'calm',
#  'came',
#  'candy',
#  'car',
#  'care',
#  'caring',
#  'carpark',
#  'carrier',
#  'cat',
#  'catcher',
#  'cats',
#  'caught',
#  'cause',
#  'ceasar',
#  'cedera',
#  'chance',
#  'change',
#  'characteristics',
#  'charges',
#  'chase',
#  'chat',
#  'choice',
#  'choose',
#  'christmas',
#  'cik',
#  'cikenet',
#  'cikenets',
#  'citta',
#  'city',
#  'clean',
#  'clearer',
#  'click',
#  'climbing',
#  'clinic',
#  'coat',
#  'coats',
#  'coco',
#  'cold',
#  'collect',
#  'collected',
#  'color',
#  'colour',
#  'come',
#  'comel',
#  'comes',
#  'comfortable',
#  'command',
#  'commit',
#  'commitment',
#  'committed',
#  'companion',
#  'companionship',
#  'company',
#  'compassion',
#  'complaints',
#  'complete',
#  'compulsory',
#  'condition',
#  'conditions',
#  'consider',
#  'contact',
#  'contacted',
#  'contacts',
#  'cooperation',
#  'corak',
#  'couldn',
#  'council',
#  'counting',
#  'couple',
#  'course',
#  'cradle',
#  'create',
#  'cross',
#  'crossed',
#  'cuddle',
#  'cuma',
#  'cured',
#  'curing',
#  'curious',
#  'currently',
#  'cute',
#  'cuteness',
#  'cutie',
#  'dad',
#  'daily',
#  'dalam',
#  'dan',
#  'darlings',
#  'dasher',
#  'datang',
#  'date',
#  'daughter',
#  'day',
#  'days',
#  'decided',
#  'deeper',
#  'definitely',
#  'deflea',
#  'defleas',
#  'dekati',
#  'delights',
#  'delivered',
#  'demodex',
#  'dengan',
#  'dent',
#  'desa',
#  'desert',
#  'deserve',
#  'detailed',
#  'details',
#  'determine',
#  'dewormed',
#  'deworming',
#  'di',
#  'dia',
#  'died',
#  'difference',
#  'different',
#  'ding',
#  'directly',
#  'disease',
#  'dob',
#  'doberman',
#  'does',
#  'doesn',
#  'dog',
#  'doggie',
#  'doggies',
#  'dogs',
#  'domesticated',
#  'don',
#  'dont',
#  'donut',
#  'door',
#  'drain',
#  'drive',
#  'driver',
#  'drop',
#  'dump',
#  'dumped',
#  'dy',
#  'eager',
#  'earlier',
#  'earn',
#  'easier',
#  'easily',
#  'easy',
#  'eat',
#  'ekor',
#  'email',
#  'emailing',
#  'embark',
#  'emel',
#  'emotionally',
#  'encourage',
#  'energetic',
#  'english',
#  'enjoy',
#  'enquiry',
#  'ensure',
#  'enter',
#  'entered',
#  'environment',
#  'eric',
#  'eve',
#  'evident',
#  'examination',
#  'example',
#  'exceptionally',
#  'existing',
#  'experience',
#  'experienced',
#  'extra',
#  'extreme',
#  'extremely',
#  'eye',
#  'eyed',
#  'eyes',
#  'face',
#  'factory',
#  'failed',
#  'fall',
#  'familiarize',
#  'families',
#  'family',
#  'fans',
#  'farm',
#  'fast',
#  'fat',
#  'father',
#  'fatter',
#  'fed',
#  'fee',
#  'feed',
#  'feeders',
#  'feeding',
#  'feel',
#  'fees',
#  'feet',
#  'feisty',
#  'female',
#  'females',
#  'fetch',
#  'fighting',
#  'filed',
#  'finally',
#  'finished',
#  'finnish',
#  'fish',
#  'fleas',
#  'flood',
#  'floor',
#  'fluffy',
#  'follow',
#  'food',
#  'football',
#  'forever',
#  'forgive',
#  'foster',
#  'fostered',
#  'fosterer',
#  'free',
#  'friend',
#  'friendly',
#  'friends',
#  'frontline',
#  'fully',
#  'fun',
#  'funds',
#  'fungus',
#  'funny',
#  'fur',
#  'future',
#  'gak',
#  'gang',
#  'garden',
#  'garfield',
#  'gave',
#  'gender',
#  'gentle',
#  'gets',
#  'getting',
#  'gf',
#  'girls',
#  'given',
#  'glue',
#  'glutton',
#  'goalie',
#  'god',
#  'godiva',
#  'goes',
#  'going',
#  'good',
#  'gorgeous',
#  'got',
#  'gou',
#  'grandma',
#  'grass',
#  'great',
#  'groomed',
#  'grooming',
#  'ground',
#  'group',
#  'grow',
#  'grown',
#  'grows',
#  'guard',
#  'guardog',
#  'guy',
#  'hair',
#  'haired',
#  'haiwan',
#  'half',
#  'hand',
#  'handle',
#  'handling',
#  'hands',
#  'handsome',
#  'happen',
#  'happy',
#  'head',
#  'healed',
#  'health',
#  'healthy',
#  'heart',
#  'heathy',
#  'heavy',
#  'heel',
#  'heihei',
#  'held',
#  'hello',
#  'help',
#  'helping',
#  'herder',
#  'hernia',
#  'hi',
#  'hide',
#  'high',
#  'hit',
#  'hitam',
#  'hold',
#  'home',
#  'homeless',
#  'homes',
#  'hometown',
#  'hope',
#  'hopefully',
#  'hoping',
#  'host',
#  'hour',
#  'hours',
#  'house',
#  'household',
#  'housing',
#  'howling',
#  'hubungi',
#  'human',
#  'humans',
#  'hungry',
#  'hunter',
#  'hv',
#  'ibu',
#  'ill',
#  'im',
#  'imagine',
#  'include',
#  'included',
#  'includes',
#  'indoor',
#  'indoors',
#  'industrial',
#  'info',
#  'inform',
#  'informed',
#  'ini',
#  'initial',
#  'inquire',
#  'inquiries',
#  'inspire',
#  'intelligence',
#  'intelligent',
#  'intentions',
#  'interactive',
#  'interested',
#  'intrested',
#  'introducing',
#  'ipoh',
#  'irresponsible',
#  'issue',
#  'itu',
#  'jabatan',
#  'jack',
#  'jadi',
#  'jalan',
#  'jantan',
#  'jasmine',
#  'jasz',
#  'jaya',
#  'jb',
#  'jenny',
#  'jinak',
#  'job',
#  'jocelyn',
#  'journey',
#  'joyful',
#  'judging',
#  'jump',
#  'jumpa',
#  'jun',
#  'just',
#  'kali',
#  'kasih',
#  'ke',
#  'keadaan',
#  'keadaanya',
#  'keeps',
#  'kekuning',
#  'kembar',
#  'kenit',
#  'kenot',
#  'kepong',
#  'kept',
#  'keputusan',
#  'kerana',
#  'kering',
#  'keris',
#  'keyad',
#  'kibbles',
#  'kicking',
#  'kids',
#  'kill',
#  'kimi',
#  'kind',
#  'kindly',
#  'kindness',
#  'kinrara',
#  'kitten',
#  'kittens',
#  'kitties',
#  'kitty',
#  'kl',
#  'klang',
#  'know',
#  'kucing',
#  'kulim',
#  'kuningan',
#  'kurang',
#  'kurap',
#  'kurapnya',
#  'labrador',
#  'lady',
#  'landed',
#  'lapponian',
#  'large',
#  'latest',
#  'law',
#  'lean',
#  'learn',
#  'learner',
#  'leashing',
#  'lebih',
#  'left',
#  'leg',
#  'lego',
#  'legs',
#  'length',
#  'lester',
#  'let',
#  'letting',
#  'license',
#  'lie',
#  'life',
#  'lighter',
#  'lightest',
#  'like',
#  'likes',
#  'litter',
#  'litters',
#  'little',
#  'live',
#  'lives',
#  'living',
#  'll',
#  'location',
#  'long',
#  'longer',
#  'look',
#  'looked',
#  'looking',
#  'looks',
#  'lost',
#  'lot',
#  'lotion',
#  'lots',
#  'lovable',
#  'love',
#  'lovely',
#  'lover',
#  'lovers',
#  'loves',
#  'loving',
#  'loyal',
#  'luckily',
#  'luka',
#  'lukanya',
#  'lulu',
#  'luna',
#  'macam',
#  'malay',
#  'malaysia',
#  'malaysian',
#  'malaysians',
#  'male',
#  'malee',
#  'males',
#  'mall',
#  'maluri',
#  'man',
#  'managed',
#  'mange',
#  'manja',
#  'mannered',
#  'march',
#  'market',
#  'masalah',
#  'master',
#  'material',
#  'mattres',
#  'max',
#  'mayo',
#  'mazuvil',
#  'mddb',
#  'mdm',
#  'meal',
#  'medical',
#  'medicine',
#  'medium',
#  'melalui',
#  'melly',
#  'membawanya',
#  'member',
#  'members',
#  'memerlukan',
#  'mencari',
#  'mengadopt',
#  'mengambil',
#  'menjaganya',
#  'menjalara',
#  'menyayangi',
#  'meow',
#  'meowing',
#  'meows',
#  'merawat',
#  'michii',
#  'mild',
#  'milk',
#  'milky',
#  'mind',
#  'minor',
#  'mins',
#  'minute',
#  'miracle',
#  'missy',
#  'mix',
#  'mixed',
#  'mochi',
#  'mohogany',
#  'molly',
#  'mom',
#  'momo',
#  'mongrel',
#  'month',
#  'months',
#  'morning',
#  'mother',
#  'motivated',
#  'moved',
#  'moving',
#  'mpsp',
#  'mr',
#  'mudah',
#  'mum',
#  'mummy',
#  'mungkin',
#  'nap',
#  'nature',
#  'near',
#  'neck',
#  'need',
#  'needa',
#  'needed',
#  'needs',
#  'neighbour',
#  'neighbourhood',
#  'neighbours',
#  'neuter',
#  'neutered',
#  'neutering',
#  'new',
#  'newspapers',
#  'ngam',
#  'nibble',
#  'nice',
#  'nickki',
#  'night',
#  'non',
#  'normal',
#  'note',
#  'notice',
#  'number',
#  'numbering',
#  'obedience',
#  'obedient',
#  'obey',
#  'object',
#  'oct',
#  'office',
#  'oil',
#  'old',
#  'open',
#  'opportunity',
#  'orang',
#  'orange',
#  'outside',
#  'outstation',
#  'owen',
#  'owner',
#  'owners',
#  'pair',
#  'pak',
#  'pal',
#  'pamper',
#  'parasites',
#  'park',
#  'pass',
#  'patches',
#  'patients',
#  'patted',
#  'pd',
#  'peanut',
#  'pebbles',
#  'pekingese',
#  'penang',
#  'people',
#  'pepper',
#  'perak',
#  'perfect',
#  'period',
#  'perlu',
#  'persian',
#  'person',
#  'personality',
#  'personally',
#  'pet',
#  'petfinder',
#  'pets',
#  'petting',
#  'photogenic',
#  'photos',
#  'picked',
#  'pics',
#  'picture',
#  'pictures',
#  'pink',
#  'pit',
#  'pitbull',
#  'pitch',
#  'place',
#  'places',
#  'play',
#  'playful',
#  'playfull',
#  'playing',
#  'plays',
#  'pleaded',
#  'pls',
#  'plss',
#  'plus',
#  'plz',
#  'poor',
#  'poorest',
#  'popularity',
#  'post',
#  'posting',
#  'potential',
#  'potty',
#  'pound',
#  'ppl',
#  'precautionary',
#  'preference',
#  'pregnant',
#  'pretty',
#  'previous',
#  'probably',
#  'problem',
#  'produce',
#  'properly',
#  'property',
#  'proses',
#  'provide',
#  'provided',
#  'pts',
#  'puchong',
#  'pulled',
#  'pup',
#  'puppies',
#  'puppy',
#  'puppydum',
#  'pups',
#  'pure',
#  'purposes',
#  'puss',
#  'putih',
#  'putting',
#  'qiqi',
#  'questions',
#  'quickly',
#  'quiet',
#  'quietly',
#  'quite',
#  'rain',
#  'raining',
#  'rainy',
#  'ran',
#  'rani',
#  'rarely',
#  'rashes',
#  'rate',
#  'raven',
#  'reach',
#  'reached',
#  'reaches',
#  'read',
#  'ready',
#  'really',
#  'received',
#  'receiving',
#  'recently',
#  'recommend',
#  'recovers',
#  'red',
#  'refer',
#  'rehome',
#  'removed',
#  'required',
#  'requirement',
#  'rescue',
#  'rescued',
#  'rescuer',
#  'resident',
#  'residential',
#  'residing',
#  'responsible',
#  'rest',
#  'resting',
#  'result',
#  'reunion',
#  'right',
#  'ringworm',
#  'rishi',
#  'rite',
#  'rm',
#  'road',
#  'roadside',
#  'rocky',
#  'rottweiler',
#  'rottwiler',
#  'routine',
#  'rub',
#  'rumah',
#  'run',
#  'runt',
#  'rusky',
#  'russel',
#  'russell',
#  'sad',
#  'safe',
#  'safety',
#  'said',
#  'sale',
#  'sangat',
#  'satu',
#  'saved',
#  'saya',
#  'scared',
#  'scheduled',
#  'schnauzer',
#  'scratched',
#  'seat',
#  'second',
#  'secure',
#  'security',
#  'sedikit',
#  'seekor',
#  'seen',
#  'segera',
#  'sek',
#  'sekarang',
#  'selangor',
#  'semakin',
#  'send',
#  'sensitive',
#  'sent',
#  'separated',
#  'separately',
#  'seperate',
#  'september',
#  'serdang',
#  'seseorang',
#  'sesiapa',
#  'sex',
#  'shaggy',
#  'shakeshand',
#  'shaking',
#  'shes',
#  'shine',
#  'shitzu',
#  'shiver',
#  'shoelaces',
#  'shop',
#  'shops',
#  'short',
#  'shots',
#  'shower',
#  'shows',
#  'shy',
#  'si',
#  'siamese',
#  'sibling',
#  'siblings',
#  'sick',
#  'signal',
#  'signs',
#  'sila',
#  'silky',
#  'silver',
#  'simple',
#  'simply',
#  'single',
#  'sini',
#  'sister',
#  'sisters',
#  'sit',
#  'situation',
#  'siu',
#  'size',
#  'sized',
#  'skin',
#  'skinny',
#  'skippy',
#  'sleep',
#  'sleeper',
#  'sleeping',
#  'sleept',
#  'sleepy',
#  'slight',
#  'slightly',
#  'small',
#  'smart',
#  'smelt',
#  'sms',
#  'soft',
#  'sold',
#  'solid',
#  'soon',
#  ...]

# %%
vectorizer
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words='english',
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
bag_of_words = vectorizer.transform(corpus)

# %%
sum_words = bag_of_words.sum(axis=0)

# %%
sum_words.shape
# Out:
# (1, 1224)

# %%
words_freq = [(word, sum_words[0, idx]) for word, idx in     vectorizer.vocabulary_.items()]

# %%
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)

# %%
words_freq
# Out:
# [('home', 40),
#  ('adoption', 33),
#  ('dog', 25),
#  ('good', 22),
#  ('adopt', 21),
#  ('cat', 21),
#  ('old', 20),
#  ('care', 18),
#  ('puppies', 18),
#  ('active', 18),
#  ('interested', 16),
#  ('contact', 16),
#  ('puppy', 16),
#  ('playful', 15),
#  ('looking', 15),
#  ('cute', 15),
#  ('friendly', 15),
#  ('just', 14),
#  ('mother', 14),
#  ('healthy', 14),
#  ('loving', 14),
#  ('male', 14),
#  ('rescued', 13),
#  ('adopter', 13),
#  ('months', 12),
#  ('pls', 12),
#  ('love', 12),
#  ('needs', 12),
#  ('need', 12),
#  ('kittens', 12),
#  ('adopted', 12),
#  ('cats', 11),
#  ('kitten', 11),
#  ('vaccination', 11),
#  ('days', 11),
#  ('female', 11),
#  ('color', 11),
#  ('new', 11),
#  ('kitty', 10),
#  ('dogs', 10),
#  ('like', 10),
#  ('house', 10),
#  ('trained', 10),
#  ('bull', 10),
#  ('people', 9),
#  ('area', 9),
#  ('email', 9),
#  ('family', 9),
#  ('started', 9),
#  ('time', 8),
#  ('adorable', 8),
#  ('long', 8),
#  ('adopters', 8),
#  ('hair', 8),
#  ('food', 8),
#  ('toilet', 8),
#  ('breed', 8),
#  ('month', 7),
#  ('little', 7),
#  ('owner', 7),
#  ('really', 7),
#  ('think', 7),
#  ('lost', 7),
#  ('human', 7),
#  ('street', 7),
#  ('pit', 7),
#  ('sold', 7),
#  ('saya', 7),
#  ('birth', 6),
#  ('sms', 6),
#  ('thanks', 6),
#  ('stray', 6),
#  ('currently', 6),
#  ('10', 6),
#  ('help', 6),
#  ('black', 6),
#  ('sweet', 6),
#  ('neutering', 6),
#  ('indoor', 6),
#  ('body', 6),
#  ('given', 6),
#  ('lovely', 6),
#  ('untuk', 6),
#  ('obedient', 6),
#  ('medical', 6),
#  ('small', 6),
#  ('finnish', 6),
#  ('spitz', 6),
#  ('14', 6),
#  ('ago', 5),
#  ('provide', 5),
#  ('vaccinated', 5),
#  ('caging', 5),
#  ('guard', 5),
#  ('loves', 5),
#  ('age', 5),
#  ('let', 5),
#  ('attention', 5),
#  ('left', 5),
#  ('manja', 5),
#  ('adopting', 5),
#  ('whatsapp', 5),
#  ('neuter', 5),
#  ('come', 5),
#  ('litter', 5),
#  ('look', 5),
#  ('caring', 5),
#  ('place', 5),
#  ('allow', 5),
#  ('feed', 5),
#  ('big', 5),
#  ('beautiful', 5),
#  ('abandoned', 5),
#  ('thank', 5),
#  ('sit', 5),
#  ('white', 5),
#  ('yang', 5),
#  ('born', 5),
#  ('weeks', 5),
#  ('pure', 5),
#  ('american', 5),
#  ('rottwiler', 5),
#  ('terrier', 5),
#  ('type', 5),
#  ('sized', 5),
#  ('head', 5),
#  ('conditions', 5),
#  ('use', 5),
#  ('app', 5),
#  ('neutered', 4),
#  ('fully', 4),
#  ('apartment', 4),
#  ('pregnant', 4),
#  ('roadside', 4),
#  ('subang', 4),
#  ('jaya', 4),
#  ('dewormed', 4),
#  ('ready', 4),
#  ('cage', 4),
#  ('details', 4),
#  ('ve', 4),
#  ('urgently', 4),
#  ('outside', 4),
#  ('gentle', 4),
#  ('likes', 4),
#  ('day', 4),
#  ('play', 4),
#  ('happy', 4),
#  ('park', 4),
#  ('strays', 4),
#  ('spayed', 4),
#  ('sleep', 4),
#  ('bark', 4),
#  ('car', 4),
#  ('factory', 4),
#  ('rescue', 4),
#  ('kucing', 4),
#  ('baby', 4),
#  ('fees', 4),
#  ('stay', 4),
#  ('cross', 4),
#  ('hope', 4),
#  ('solid', 4),
#  ('potential', 4),
#  ('willing', 4),
#  ('spay', 4),
#  ('fat', 4),
#  ('di', 4),
#  ('easily', 4),
#  ('angel', 4),
#  ('week', 4),
#  ('year', 4),
#  ('environment', 4),
#  ('life', 4),
#  ('drain', 4),
#  ('skin', 4),
#  ('health', 4),
#  ('free', 4),
#  ('feel', 4),
#  ('lapponian', 4),
#  ('herder', 4),
#  ('sale', 4),
#  ('shows', 4),
#  ('chance', 4),
#  ('rescuer', 4),
#  ('nibble', 3),
#  ('clinic', 3),
#  ('space', 3),
#  ('near', 3),
#  ('bring', 3),
#  ('dumped', 3),
#  ('tying', 3),
#  ('waiting', 3),
#  ('handsome', 3),
#  ('boy', 3),
#  ('young', 3),
#  ('want', 3),
#  ('high', 3),
#  ('soft', 3),
#  ('super', 3),
#  ('recommend', 3),
#  ('half', 3),
#  ('night', 3),
#  ('deworming', 3),
#  ('vaccinate', 3),
#  ('hi', 3),
#  ('pet', 3),
#  ('taking', 3),
#  ('homes', 3),
#  ('bandar', 3),
#  ('menjalara', 3),
#  ('taman', 3),
#  ('landed', 3),
#  ('mom', 3),
#  ('run', 3),
#  ('able', 3),
#  ('jantan', 3),
#  ('colour', 3),
#  ('companion', 3),
#  ('large', 3),
#  ('calm', 3),
#  ('fur', 3),
#  ('sent', 3),
#  ('saved', 3),
#  ('follow', 3),
#  ('sister', 3),
#  ('pair', 3),
#  ('years', 3),
#  ('mummy', 3),
#  ('open', 3),
#  ('dengan', 3),
#  ('streets', 3),
#  ('malaysian', 3),
#  ('siblings', 3),
#  ('decided', 3),
#  ('jack', 3),
#  ('xiao', 3),
#  ('dy', 3),
#  ('usj', 3),
#  ('vet', 3),
#  ('playing', 3),
#  ('pics', 3),
#  ('ur', 3),
#  ('pups', 3),
#  ('mix', 3),
#  ('personality', 3),
#  ('pup', 3),
#  ('fee', 3),
#  ('don', 3),
#  ('eyes', 3),
#  ('office', 3),
#  ('know', 3),
#  ('try', 3),
#  ('brother', 3),
#  ('kitties', 3),
#  ('size', 3),
#  ('lego', 3),
#  ('received', 3),
#  ('perfect', 3),
#  ('available', 3),
#  ('characteristics', 3),
#  ('initial', 3),
#  ('ensure', 3),
#  ('penang', 3),
#  ('location', 3),
#  ('mochi', 3),
#  ('momo', 3),
#  ('molly', 3),
#  ('friend', 3),
#  ('dan', 3),
#  ('kurap', 3),
#  ('yg', 3),
#  ('energetic', 2),
#  ('household', 2),
#  ('responsible', 2),
#  ('yesterday', 2),
#  ('temporary', 2),
#  ('gave', 2),
#  ('seen', 2),
#  ('cutie', 2),
#  ('came', 2),
#  ('feeding', 2),
#  ('father', 2),
#  ('hometown', 2),
#  ('better', 2),
#  ('garden', 2),
#  ('meow', 2),
#  ('kali', 2),
#  ('wakes', 2),
#  ('quiet', 2),
#  ('busy', 2),
#  ('hour', 2),
#  ('second', 2),
#  ('forever', 2),
#  ('info', 2),
#  ('photos', 2),
#  ('scared', 2),
#  ('lovers', 2),
#  ('persian', 2),
#  ('earlier', 2),
#  ('kepong', 2),
#  ('desa', 2),
#  ('city', 2),
#  ('sri', 2),
#  ('malaysia', 2),
#  ('looks', 2),
#  ('taken', 2),
#  ('moving', 2),
#  ('great', 2),
#  ('loyal', 2),
#  ('12', 2),
#  ('command', 2),
#  ('eat', 2),
#  ('ppl', 2),
#  ('touch', 2),
#  ('im', 2),
#  ('mr', 2),
#  ('guy', 2),
#  ('safe', 2),
#  ('driver', 2),
#  ('stop', 2),
#  ('kindness', 2),
#  ('allowed', 2),
#  ('cause', 2),
#  ('work', 2),
#  ('clean', 2),
#  ('comel', 2),
#  ('badan', 2),
#  ('tapi', 2),
#  ('telinga', 2),
#  ('macam', 2),
#  ('quite', 2),
#  ('spot', 2),
#  ('lovable', 2),
#  ('godiva', 2),
#  ('caught', 2),
#  ('catcher', 2),
#  ('fed', 2),
#  ('period', 2),
#  ('gorgeous', 2),
#  ('medium', 2),
#  ('picked', 2),
#  ('wanna', 2),
#  ('garfield', 2),
#  ('daily', 2),
#  ('grooming', 2),
#  ('short', 2),
#  ('easy', 2),
#  ('brown', 2),
#  ('patches', 2),
#  ('pets', 2),
#  ('ke', 2),
#  ('sick', 2),
#  ('welcome', 2),
#  ('plus', 2),
#  ('door', 2),
#  ('si', 2),
#  ('ini', 2),
#  ('menjaganya', 2),
#  ('sekarang', 2),
#  ('doesn', 2),
#  ('attached', 2),
#  ('owners', 2),
#  ('fostered', 2),
#  ('shy', 2),
#  ('failed', 2),
#  ('turn', 2),
#  ('tame', 2),
#  ('got', 2),
#  ('leg', 2),
#  ('gf', 2),
#  ('mayo', 2),
#  ('veterinar', 2),
#  ('rm', 2),
#  ('jalan', 2),
#  ('way', 2),
#  ('treated', 2),
#  ('treat', 2),
#  ('future', 2),
#  ('haired', 2),
#  ('suitable', 2),
#  ('labrador', 2),
#  ('jocelyn', 2),
#  ('till', 2),
#  ('fatter', 2),
#  ('delivered', 2),
#  ('miracle', 2),
#  ('gender', 2),
#  ('change', 2),
#  ('does', 2),
#  ('rashes', 2),
#  ('nice', 2),
#  ('coat', 2),
#  ('sisters', 2),
#  ('receiving', 2),
#  ('needed', 2),
#  ('poor', 2),
#  ('fosterer', 2),
#  ('potty', 2),
#  ('training', 2),
#  ('males', 2),
#  ('females', 2),
#  ('read', 2),
#  ('compulsory', 2),
#  ('vaccinations', 2),
#  ('shots', 2),
#  ('apply', 2),
#  ('right', 2),
#  ('person', 2),
#  ('ding', 2),
#  ('nature', 2),
#  ('behaved', 2),
#  ('bai', 2),
#  ('dad', 2),
#  ('extreme', 2),
#  ('signs', 2),
#  ('alertness', 2),
#  ('watch', 2),
#  ('barking', 2),
#  ('howling', 2),
#  ('walking', 2),
#  ('fighting', 2),
#  ('25', 2),
#  ('pictures', 2),
#  ('fluffy', 2),
#  ('yearly', 2),
#  ('member', 2),
#  ('living', 2),
#  ('pound', 2),
#  ('1st', 2),
#  ('train', 2),
#  ('story', 2),
#  ('reach', 2),
#  ('lulu', 2),
#  ('kind', 2),
#  ('nickki', 2),
#  ('hand', 2),
#  ('choose', 2),
#  ('fish', 2),
#  ('oil', 2),
#  ('farm', 2),
#  ('workshop', 2),
#  ('property', 2),
#  ('tick', 2),
#  ('stage', 2),
#  ('adjustable', 2),
#  ('babies', 2),
#  ('morning', 2),
#  ('agree', 2),
#  ('6th', 2),
#  ('visit', 2),
#  ('foster', 2),
#  ('pass', 2),
#  ('lover', 2),
#  ('klang', 2),
#  ('telah', 2),
#  ('lukanya', 2),
#  ('lebih', 2),
#  ('tidak', 2),
#  ('sesiapa', 2),
#  ('sudi', 2),
#  ('dia', 2),
#  ('spca', 2),
#  ('apr', 2),
#  ('ball', 1),
#  ('cuteness', 1),
#  ('couple', 1),
#  ('scheduled', 1),
#  ('result', 1),
#  ('funds', 1),
#  ('shaking', 1),
#  ('irresponsible', 1),
#  ('shops', 1),
#  ('hours', 1),
#  ('acceptable', 1),
#  ('tie', 1),
#  ('precautionary', 1),
#  ('purposes', 1),
#  ('alert', 1),
#  ('obedience', 1),
#  ('master', 1),
#  ('plz', 1),
#  ('pal', 1),
#  ('shoelaces', 1),
#  ('chase', 1),
#  ('imagine', 1),
#  ('brat', 1),
#  ('grows', 1),
#  ('hunter', 1),
#  ('ipoh', 1),
#  ('taiping', 1),
#  ('number', 1),
#  ('mazuvil', 1),
#  ('bulat', 1),
#  ('perak', 1),
#  ('travel', 1),
#  ('lot', 1),
#  ('rite', 1),
#  ('siu', 1),
#  ('pak', 1),
#  ('13', 1),
#  ('6puppies', 1),
#  ('2female', 1),
#  ('feisty', 1),
#  ('neighbours', 1),
#  ('sure', 1),
#  ('sex', 1),
#  ('pitch', 1),
#  ('minute', 1),
#  ('meows', 1),
#  ('rarely', 1),
#  ('cuddle', 1),
#  ('sleepy', 1),
#  ('nap', 1),
#  ('toys', 1),
#  ('keeps', 1),
#  ('spend', 1),
#  ('normal', 1),
#  ('routine', 1),
#  ('single', 1),
#  ('peanut', 1),
#  ('abused', 1),
#  ('lester', 1),
#  ('jenny', 1),
#  ('required', 1),
#  ('posting', 1),
#  ('befriended', 1),
#  ('ground', 1),
#  ('floor', 1),
#  ('bathroom', 1),
#  ('evident', 1),
#  ('batch', 1),
#  ('bukit', 1),
#  ('maluri', 1),
#  ('迷途犬被尋獲', 1),
#  ('甲洞孟加拉惹', 1),
#  ('武吉馬魯里', 1),
#  ('小狗被發現地點', 1),
#  ('kl', 1),
#  ('大馬吉隆坡甲洞孟加拉惹', 1),
#  ('狗兒如何被發現', 1),
#  ('entered', 1),
#  ('staying', 1),
#  ('迷途小狗自行進我居住地', 1),
#  ('condition', 1),
#  ('情況', 1),
#  ('雖好像幾天沒進食', 1),
#  ('看起來健康', 1),
#  ('頸上系有紅帶', 1),
#  ('目前甲洞孟加拉惹住宅區保安處看顧', 1),
#  ('neck', 1),
#  ('tied', 1),
#  ('red', 1),
#  ('belt', 1),
#  ('security', 1),
#  ('housing', 1),
#  ('moved', 1),
#  ('neighbourhood', 1),
#  ('grandma', 1),
#  ('neighbour', 1),
#  ('pleaded', 1),
#  ('fun', 1),
#  ('plays', 1),
#  ('football', 1),
#  ('goalie', 1),
#  ('guardog', 1),
#  ('abroad', 1),
#  ('max', 1),
#  ('shes', 1),
#  ('obey', 1),
#  ('wht', 1),
#  ('told', 1),
#  ('example', 1),
#  ('shakeshand', 1),
#  ('english', 1),
#  ('tamil', 1),
#  ('thr', 1),
#  ('suspicius', 1),
#  ('act', 1),
#  ('sleept', 1),
#  ('mattres', 1),
#  ('cradle', 1),
#  ('whn', 1),
#  ('anyybody', 1),
#  ('intrested', 1),
#  ('addopt', 1),
#  ('plss', 1),
#  ('tom', 1),
#  ('thx', 1),
#  ('petfinder', 1),
#  ('market', 1),
#  ('kill', 1),
#  ('kicking', 1),
#  ('trying', 1),
#  ('hide', 1),
#  ('ran', 1),
#  ('hit', 1),
#  ('notice', 1),
#  ('pulled', 1),
#  ('luckily', 1),
#  ('shop', 1),
#  ('19', 1),
#  ('situation', 1),
#  ('beauty', 1),
#  ('2months', 1),
#  ('directly', 1),
#  ('rehome', 1),
#  ('date', 1),
#  ('oct', 1),
#  ('30th', 1),
#  ('melly', 1),
#  ('sangat', 1),
#  ('vokal', 1),
#  ('tootsie', 1),
#  ('putih', 1),
#  ('ekor', 1),
#  ('hitam', 1),
#  ('kekuning', 1),
#  ('kuningan', 1),
#  ('bo', 1),
#  ('corak', 1),
#  ('tompok', 1),
#  ('lightest', 1),
#  ('michii', 1),
#  ('abang', 1),
#  ('kembar', 1),
#  ('subtle', 1),
#  ('belakang', 1),
#  ('missy', 1),
#  ('curious', 1),
#  ('adventurous', 1),
#  ('voice', 1),
#  ('serdang', 1),
#  ('residential', 1),
#  ('group', 1),
#  ('friends', 1),
#  ('team', 1),
#  ('afraid', 1),
#  ('believed', 1),
#  ('unigue', 1),
#  ('coats', 1),
#  ('eye', 1),
#  ('length', 1),
#  ('absolutely', 1),
#  ('properly', 1),
#  ('kenit', 1),
#  ('kenot', 1),
#  ('owen', 1),
#  ('keyad', 1),
#  ('techit', 1),
#  ('pamper', 1),
#  ('donut', 1),
#  ('doggie', 1),
#  ('domesticated', 1),
#  ('strangers', 1),
#  ('sleeping', 1),
#  ('bed', 1),
#  ('lie', 1),
#  ('demodex', 1),
#  ('cured', 1),
#  ('borne', 1),
#  ('hello', 1),
#  ('cikenets', 1),
#  ('fans', 1),
#  ('inform', 1),
#  ('cikenet', 1),
#  ('resident', 1),
#  ('hands', 1),
#  ('groomed', 1),
#  ('deflea', 1),
#  ('wt', 1),
#  ('kept', 1),
#  ('indoors', 1),
#  ('brushing', 1),
#  ('skinny', 1),
#  ('tall', 1),
#  ('doberman', 1),
#  ('authorities', 1),
#  ('dont', 1),
#  ('issue', 1),
#  ('license', 1),
#  ('meowing', 1),
#  ('feet', 1),
#  ('stand', 1),
#  ('lean', 1),
#  ('quietly', 1),
#  ('start', 1),
#  ('benji', 1),
#  ('kimi', 1),
#  ('shitzu', 1),
#  ('shaggy', 1),
#  ('face', 1),
#  ('lots', 1),
#  ('tatao', 1),
#  ('betine', 1),
#  ('ank', 1),
#  ('pd', 1),
#  ('ibu', 1),
#  ('gak', 1),
#  ('boiboi', 1),
#  ('daughter', 1),
#  ('tuition', 1),
#  ('behave', 1),
#  ('preference', 1),
#  ('existing', 1),
#  ('experience', 1),
#  ('enquiry', 1),
#  ('memerlukan', 1),
#  ('seseorang', 1),
#  ('boleh', 1),
#  ('menyayangi', 1),
#  ('perlu', 1),
#  ('segera', 1),
#  ('kerana', 1),
#  ('keadaan', 1),
#  ('bahaya', 1),
#  ('baginya', 1),
#  ('tinggal', 1),
#  ('sini', 1),
#  ('whisky', 1),
#  ('unnecessarily', 1),
#  ('gets', 1),
#  ('wish', 1),
#  ('sports', 1),
#  ('temporarily', 1),
#  ('11', 1),
#  ('march', 1),
#  ('working', 1),
#  ('malaysians', 1),
#  ('families', 1),
#  ('timid', 1),
#  ('younger', 1),
#  ('blossom', 1),
#  ('note', 1),
#  ('wait', 1),
#  ('emotionally', 1),
#  ('putting', 1),
#  ('easier', 1),
#  ('track', 1),
#  ('apologise', 1),
#  ('contacted', 1),
#  ('unable', 1),
#  ('takes', 1),
#  ('contacts', 1),
#  ('dob', 1),
#  ('jun', 1),
#  ('defleas', 1),
#  ('playfull', 1),
#  ('funny', 1),
#  ('siamese', 1),
#  ('patted', 1),
#  ('blue', 1),
#  ('eyed', 1),
#  ('recently', 1),
#  ('scratched', 1),
#  ('russell', 1),
#  ('crossed', 1),
#  ('joyful', 1),
#  ('legs', 1),
#  ('stubby', 1),
#  ('tail', 1),
#  ('wags', 1),
#  ('vigourously', 1),
#  ('atwhat', 1),
#  ('delights', 1),
#  ('gang', 1),
#  ('troop', 1),
#  ('terrace', 1),
#  ('gou', 1),
#  ('hv', 1),
#  ('taipan', 1),
#  ('special', 1),
#  ('rate', 1),
#  ('rani', 1),
#  ('works', 1),
#  ('address', 1),
#  ('uep', 1),
#  ('11a', 1),
#  ('1g', 1),
#  ('selangor', 1),
#  ('tel', 1),
#  ('couldn', 1),
#  ('climbing', 1),
#  ('seat', 1),
#  ('reached', 1),
#  ('walked', 1),
#  ('smelt', 1),
#  ('familiarize', 1),
#  ('tried', 1),
#  ('tackle', 1),
#  ('petting', 1),
#  ('heavy', 1),
#  ('sleeper', 1),
#  ('cik', 1),
#  ('amer', 1),
#  ('letting', 1),
#  ('ll', 1),
#  ('upload', 1),
#  ('latest', 1),
#  ('soon', 1),
#  ('mannered', 1),
#  ('ill', 1),
#  ('previous', 1),
#  ('detailed', 1),
#  ('examination', 1),
#  ('wounds', 1),
#  ('eager', 1),
#  ('shower', 1),
#  ('girls', 1),
#  ('boys', 1),
#  ('adult', 1),
#  ('questions', 1),
#  ('ask', 1),
#  ('determine', 1),
#  ('beloved', 1),
#  ('heart', 1),
#  ('soul', 1),
#  ('simple', 1),
#  ('job', 1),
#  ('waste', 1),
#  ('emailing', 1),
#  ('cooperation', 1),
#  ('judging', 1),
#  ('hernia', 1),
#  ('removed', 1),
#  ('spaying', 1),
#  ('mdm', 1),
#  ('bit', 1),
#  ('talkative', 1),
#  ('bouncer', 1),
#  ('grow', 1),
#  ('course', 1),
#  ('world', 1),
#  ('requirement', 1),
#  ('commit', 1),
#  ('collect', 1),
#  ('choice', 1),
#  ('produce', 1),
#  ('looked', 1),
#  ('alike', 1),
#  ('different', 1),
#  ('difference', 1),
#  ('residing', 1),
#  ('bodies', 1),
#  ('asked', 1),
#  ('getting', 1),
#  ('vitamin', 1),
#  ('total', 1),
#  ('puppydum', 1),
#  ('managed', 1),
#  ('believe', 1),
#  ('happen', 1),
#  ('create', 1),
#  ('counting', 1),
#  ('lives', 1),
#  ('companionship', 1),
#  ('medicine', 1),
#  ('bro', 1),
#  ('law', 1),
#  ('malay', 1),
#  ('exceptionally', 1),
#  ('affectionate', 1),
#  ('temperament', 1),
#  ('interactive', 1),
#  ('tails', 1),
#  ('actually', 1),
#  ('brothers', 1),
#  ('calico', 1),
#  ('mum', 1),
#  ('going', 1),
#  ('weaker', 1),
#  ('rest', 1),
#  ('runt', 1),
#  ('treatment', 1),
#  ('finally', 1),
#  ('embark', 1),
#  ('journey', 1),
#  ('strongly', 1),
#  ('encourage', 1),
#  ('extra', 1),
#  ('boost', 1),
#  ('meal', 1),
#  ('times', 1),
#  ('glutton', 1),
#  ('skippy', 1),
#  ('kids', 1),
#  ('handle', 1),
#  ('ceasar', 1),
#  ('intelligent', 1),
#  ('wanted', 1),
#  ('2years', 1),
#  ('2month', 1),
#  ('teenager', 1),
#  ('orange', 1),
#  ('puss', 1),
#  ('boots', 1),
#  ('probably', 1),
#  ('milk', 1),
#  ('bottle', 1),
#  ('accident', 1),
#  ('feeders', 1),
#  ('healed', 1),
#  ('slight', 1),
#  ('dent', 1),
#  ('surgery', 1),
#  ('humans', 1),
#  ('sooo', 1),
#  ('stuck', 1),
#  ('consider', 1),
#  ('milky', 1),
#  ('dump', 1),
#  ('ard', 1),
#  ('homeless', 1),
#  ('resting', 1),
#  ('christmas', 1),
#  ('eve', 1),
#  ('died', 1),
#  ('bcos', 1),
#  ('raining', 1),
#  ('said', 1),
#  ('pink', 1),
#  ('mongrel', 1),
#  ('definitely', 1),
#  ('kindly', 1),
#  ('click', 1),
#  ('clearer', 1),
#  ('view', 1),
#  ('___________________________________________________', 1),
#  ('introducing', 1),
#  ('yelpers', 1),
#  ('24th', 1),
#  ('september', 1),
#  ('kibbles', 1),
#  ('fleas', 1),
#  ('parasites', 1),
#  ('frontline', 1),
#  ('spray', 1),
#  ('worming', 1),
#  ('rusky', 1),
#  ('rocky', 1),
#  ('dasher', 1),
#  ('whiskey', 1),
#  ('barkly', 1),
#  ('raven', 1),
#  ('jasmine', 1),
#  ('candy', 1),
#  ('________________________________________________', 1),
#  ('caged', 1),
#  ('leashing', 1),
#  ('inquire', 1),
#  ('drop', 1),
#  ('darlings', 1),
#  ('ben', 1),
#  ('enjoy', 1),
#  ('company', 1),
#  ('beautifully', 1),
#  ('separately', 1),
#  ('held', 1),
#  ('stroked', 1),
#  ('almond', 1),
#  ('pretty', 1),
#  ('rub', 1),
#  ('tummy', 1),
#  ('sad', 1),
#  ('away', 1),
#  ('comes', 1),
#  ('luna', 1),
#  ('seperate', 1),
#  ('included', 1),
#  ('carrier', 1),
#  ('material', 1),
#  ('jasz', 1),
#  ('schnauzer', 1),
#  ('adopts', 1),
#  ('places', 1),
#  ('qiqi', 1),
#  ('sibling', 1),
#  ('flood', 1),
#  ('separated', 1),
#  ('breeds', 1),
#  ('russel', 1),
#  ('tan', 1),
#  ('ty', 1),
#  ('industrial', 1),
#  ('curing', 1),
#  ('minor', 1),
#  ('disease', 1),
#  ('problem', 1),
#  ('ringworm', 1),
#  ('wants', 1),
#  ('handling', 1),
#  ('litters', 1),
#  ('include', 1),
#  ('pitbull', 1),
#  ('extremely', 1),
#  ('strength', 1),
#  ('15', 1),
#  ('numbering', 1),
#  ('mohogany', 1),
#  ('slightly', 1),
#  ...]
